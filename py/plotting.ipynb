# %%
import seaborn as sns, numpy as np, matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(18, 12), sharex = 'col')
axes[0,0].set_title('Timesteps Taken', fontsize = 13)
axes[0,1].set_title('Average Boarding Times', fontsize = 13)
axes[0,2].set_title('Average Stowage Time', fontsize = 13)
axes[0,3].set_title('Average Waiting Time', fontsize = 13)
axes[0,4].set_title('Average # of Stops', fontsize = 13)
axes[0,0].set_ylabel('Our Method', fontsize = 13, labelpad = 10)
axes[1,0].set_ylabel('Reverse Pyramid', fontsize = 13, labelpad = 10)
axes[2,0].set_ylabel('Boarding by Section', fontsize = 13, labelpad = 4)
axes[3,0].set_ylabel('Boarding by Seat', fontsize = 13, labelpad = 10)
axes[4,0].set_ylabel('Random', fontsize = 13, labelpad = 5)

sns.distplot(np.load('random_time.npy'), ax = axes[4,0], bins = 9)
sns.distplot(np.load('random_board_avg.npy'), ax = axes[4,1], bins = 9)
sns.distplot(np.load('random_bag_avg.npy'), ax = axes[4,2], bins = 9)
sns.distplot(np.load('random_wait_avg.npy'), ax = axes[4,3], bins = 9)
sns.distplot(np.load('random_stop_avg.npy'), ax = axes[4,4], bins = 9)
sns.distplot(np.load('oi_time.npy'), ax = axes[3,0], bins = 9)
sns.distplot(np.load('oi_board_avg.npy'), ax = axes[3,1], bins = 9)
sns.distplot(np.load('oi_bag_avg.npy'), ax = axes[3,2], bins = 9)
sns.distplot(np.load('oi_wait_avg.npy'), ax = axes[3,3], bins = 9)
sns.distplot(np.load('oi_stop_avg.npy'), ax = axes[3,4], bins = 9)
sns.distplot(np.load('bf_time.npy'), ax = axes[2,0], bins = 9)
sns.distplot(np.load('bf_board_avg.npy'), ax = axes[2,1], bins = 9)
sns.distplot(np.load('bf_bag_avg.npy'), ax = axes[2,2], bins = 9)
sns.distplot(np.load('bf_wait_avg.npy'), ax = axes[2,3], bins = 9)
sns.distplot(np.load('bf_stop_avg.npy'), ax = axes[2,4], bins = 9)
sns.distplot(np.load('rp_time.npy'), ax = axes[1,0], bins = 9)
sns.distplot(np.load('rp_board_avg.npy'), ax = axes[1,1], bins = 9)
sns.distplot(np.load('rp_bag_avg.npy'), ax = axes[1,2], bins = 9)
sns.distplot(np.load('rp_wait_avg.npy'), ax = axes[1,3], bins = 9)
sns.distplot(np.load('rp_stop_avg.npy'), ax = axes[1,4], bins = 9)
sns.distplot(np.load('our_time.npy'), ax = axes[0,0], bins = 9, color = 'mediumseagreen')
sns.distplot(np.load('our_board_avg.npy'), ax = axes[0,1], bins = 9, color = 'mediumseagreen')
sns.distplot(np.load('our_bag_avg.npy'), ax = axes[0,2], bins = 9, color = 'mediumseagreen')
sns.distplot(np.load('our_wait_avg.npy'), ax = axes[0,3], bins = 9, color = 'mediumseagreen')
sns.distplot(np.load('our_stop_avg.npy'), ax = axes[0,4], bins = 9, color = 'mediumseagreen')

plt.savefig('hist.pdf')

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 5, figsize = (18, 7.2), sharex = 'col')
axes[0,0].set_title('Timesteps Taken', fontsize = 13)
axes[0,1].set_title('Average Boarding Times', fontsize = 13)
axes[0,2].set_title('Average Stowage Time', fontsize = 13)
axes[0,3].set_title('Average Waiting Time', fontsize = 13)
axes[0,4].set_title('Average # of Stops', fontsize = 13)
axes[0,0].set_ylabel('Our Method', fontsize = 13, labelpad = 10)
axes[1,0].set_ylabel('Boarding by Seat', fontsize = 13)
axes[2,0].set_ylabel('Random', fontsize = 13, labelpad = 10)

sns.distplot(np.load('bg_two_time.npy'), ax = axes[0,0], bins = 9, color = 'mediumseagreen')
sns.distplot(np.load('bg_two_board_avg.npy'), ax = axes[0,1], bins = 9, color = 'mediumseagreen')
sns.distplot(np.load('bg_two_bag_avg.npy'), ax = axes[0,2], bins = 9 )
sns.distplot(np.load('bg_two_wait_avg.npy'), ax = axes[0,3], bins = 9, color = 'mediumseagreen')
sns.distplot(np.load('bg_two_stop_avg.npy'), ax = axes[0,4], bins = 9, color = 'mediumseagreen')
sns.distplot(np.load('oi_two_time.npy'), ax = axes[1,0], bins = 9)
sns.distplot(np.load('oi_two_board_avg.npy'), ax = axes[1,1], bins = 9)
sns.distplot(np.load('oi_two_bag_avg.npy'), ax = axes[1,2], bins = 9,color = 'mediumseagreen')
sns.distplot(np.load('oi_two_wait_avg.npy'), ax = axes[1,3], bins = 9)
sns.distplot(np.load('oi_two_stop_avg.npy'), ax = axes[1,4], bins = 9)
sns.distplot(np.load('rand_two_time.npy'), ax = axes[2,0], bins = 9)
sns.distplot(np.load('rand_two_board_avg.npy'), ax = axes[2,1], bins = 9)
sns.distplot(np.load('rand_two_bag_avg.npy'), ax = axes[2,2], bins = 9)
sns.distplot(np.load('rand_two_wait_avg.npy'), ax = axes[2,3], bins = 9)
sns.distplot(np.load('rand_two_stop_avg.npy'), ax = axes[2,4], bins = 9)

plt.savefig('doubleaisle.pdf')

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 1)
sns.violinplot(np.load('dis_time.npy'), ax = axes[0])
sns.violinplot(np.load('dis_wait_avg.npy'), ax = axes[1])
sns.violinplot(np.load('dis_board_avg.npy'), ax = axes[2])

# %%
import seaborn as sns, numpy as np, matplotlib.pyplot as plt
sns.distplot(np.random.poisson(1,30000), bins = 11)
plt.xlabel('Factor')
plt.ylabel('Frequency')
plt.savefig('bagdist.pdf')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 3, figsize = (18, 4.8), sharex = 'col')
axes[0,0].set_title('Timesteps Taken', fontsize = 13)
axes[0,1].set_title('Average Disembarking Times', fontsize = 13)
axes[0,2].set_title('Average # of Stops', fontsize = 13)
axes[0,0].set_ylabel('Our Method', fontsize = 13, labelpad = 10)
axes[1,0].set_ylabel('Random Baggage', fontsize = 13)

sns.distplot(np.load('dis_time.npy'), ax = axes[0,0], bins = 9, color = 'mediumseagreen')
sns.distplot(np.load('dis_board_avg.npy'), ax = axes[0,1], bins = 9, color = 'mediumseagreen')
#sns.distplot(np.load('bg_two_bag_avg.npy'), ax = axes[0,2], bins = 9 )
#sns.distplot(np.load('bg_two_wait_avg.npy'), ax = axes[0,3], bins = 9, color = 'mediumseagreen')
sns.distplot(np.load('dis_stop_avg.npy'), ax = axes[0,2], bins = 9, color = 'mediumseagreen')
sns.distplot(np.load('dis2_time.npy'), ax = axes[1,0], bins = 9)
sns.distplot(np.load('dis2_board_avg.npy'), ax = axes[1,1], bins = 9)
#sns.distplot(np.load('oi_two_bag_avg.npy'), ax = axes[1,2], bins = 9,color = 'mediumseagreen')
#sns.distplot(np.load('oi_two_wait_avg.npy'), ax = axes[1,3], bins = 9)
sns.distplot(np.load('dis2_stop_avg.npy'), ax = axes[1,2], bins = 9)

plt.savefig('dis.pdf')

# %%
int(3.07*10**(-5))
# Out:
# 0

# %%
np.e
# Out:
# 2.718281828459045
